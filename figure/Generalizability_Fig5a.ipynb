# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

import argparse
from collections import OrderedDict

import yaml
import csv
import time
from datetime import datetime
import shutil
import logging
from typing import Tuple, Sequence, Any, Union
from functools import partial

from jax import random
import jax.numpy as jnp
import jax
from brax.io import html
from brax import jumpy as jp
from brax import envs
from IPython.display import HTML

os.environ['CUDA_VISIBLE_DEVICES'] = ''

import evojax
from evojax.util import get_params_format_fn
from evojax.task.base import TaskState
from evojax.policy.base import PolicyState
from evojax.policy.base import PolicyNetwork
from flax.struct import dataclass
from flax import linen as nn

from evojax.task.brax_task import BraxTask
from evojax.task.gym_task import Gym
from evojax.algo import PGPE, OpenES
from evojax import ObsNormalizer
from evojax import SimManager

sns.set_style('darkgrid')
sns.set_palette('muted', desat=.6)
sns.set_context("notebook", font_scale=1.0,
                rc={"lines.linewidth": 2.5})

root_dir = '/home/floyed/Metaplasticity__Unifying_Learning_and_Homeostatic_Plasticity_in_Spiking_Neural_Networks'
output_dir = '/home/floyed/evojax/examples/metaplasticity_plot/injury'

# %%
def load_model(model_dir: str, fname='best.npz') -> Tuple[np.ndarray, np.ndarray, int, float, int]:
    model_file = os.path.join(model_dir, fname)
    if not os.path.exists(model_file):
        raise ValueError('Model file {} does not exist.')
    with np.load(model_file, allow_pickle=True) as data:
        params = data['params']
        obs_params = data['obs_params']
        epoch = data.get('epoch', 0)
        score = data.get('score', -float('Inf'))
        steps = data.get('steps', 0)
    return params, obs_params, epoch, score, steps

# %% [markdown]
# ### Eval with injury

# %%
def eval_with_injury(policy, env_name, obs_normalizer, params, obs_params, target=None, injury=False, plot=True):
    if target is None:
        target = {}
    env_fn = envs.create_fn(
        env_name=env_name,
        legacy_spring=True,
        # terminate_when_unhealthy=args.terminate_when_unhealthy,
        **target
    )
    env = env_fn()
    # state = env.reset(rng=jp.random_prngkey(seed=0))
    task_reset_fn = jax.jit(env.reset)
    policy_reset_fn = jax.jit(policy.reset)
    step_fn = jax.jit(env.step)
    act_fn = jax.jit(policy.get_actions)
    # update_fn = jax.jit(policy.update_fn) if hasattr(policy, 'update_fn') else lambda params, p_state, t_state: p_state
    obs_norm_fn = jax.jit(obs_normalizer.normalize_obs)

    total_reward = 0
    rollout = []
    rewards = []
    ws = []
    rng = jax.random.PRNGKey(42 + 1)
    task_state = task_reset_fn(rng=rng)
    policy_state = policy_reset_fn(task_state)

    step = 0
    while not task_state.done:
        rollout.append(task_state)
        task_state = task_state.replace(
            obs=obs_norm_fn(task_state.obs[None, :], obs_params))
        # jax.debug.breakpoint()
        act, policy_state = act_fn(task_state, params[None, :], policy_state)
        # For 50 steps, completely zero out the weights to see if the policy can
        # relearn weights that allow the ant to walk.
        if step > 500 and step < 550 and injury:
            policy_state.fast_Ws[1] *= 0

        # jax.debug.breakpoint()
        task_state = task_state.replace(obs=task_state.obs[0])
        task_state = step_fn(task_state, act[0])
        # task_state = env.step(task_state, act[0])
        # policy_state = update_fn(params[None, :], policy_state, None)
        total_reward = total_reward + task_state.reward
        rewards.append(task_state.reward)
        # Record the weights every 10 steps for visualisations.
        if hasattr(policy_state, 'fast_Ws') and step % 10 == 0:
            ws.append(policy_state.fast_Ws)
        step += 1

        if step % 100 == 0 and plot:
            print('[Eval with injury] {}, reward:{:.3e}'.format(step, total_reward))
    print('[Eval with injury] rollout reward = {}'.format(total_reward))

    if plot:
        ws = list(zip(*ws))
        for i, w in enumerate(ws):
            w = np.array(jnp.concatenate(w)[jnp.newaxis, :, jnp.newaxis, :, :])
            # TODO: w

        html.save_html(os.path.join(output_dir, 'eval_with_injury_{}.html'.format(target)), env.sys, [s.qp for s in rollout])

        fig, ax = plt.subplots()
        ax.plot(rewards)
        plt.savefig(os.path.join(output_dir, 'BraxMetaLearning_{}.pdf').format(target))

    return rewards, rollout

# %% [markdown]
# #### Meta

# %%
env = 'swimmer_dir'  # ur5e  fetch  swimmer_dir  halfcheetah_vel  ant_dir
num_tasks = 8
hidden_dims = [128]

resume = f'{root_dir}/checkpoints/RL_exp/meta/'


train_task = BraxTask(
    env_name=env,
    test=False,
    num_tasks=num_tasks
    # terminate_when_unhealthy=args.terminate_when_unhealthy
)
policy = getattr(evojax.policy, 'MetaStdpMLPPolicy')(
    input_dim=train_task.obs_shape[0],
    hidden_dims=[
        *hidden_dims,
    ],
    output_dim=train_task.act_shape[0],
)

best_params, obs_params, epoch, best_score, steps = load_model(model_dir=resume, fname=f'{env}.npz')
obs_normalizer = ObsNormalizer(obs_shape=train_task.obs_shape, task_info_holder=train_task.task_info_holder)
# Out:
# (9,) (2,)
# (9,)

# %% [markdown]
# #### Base

# %%
def eval_with_injury_base(policy, env_name, obs_normalizer, params, obs_params, target=None, injury=False, plot=True):
    # def step_once(carry, input_data):
    #     (task_state, policy_state, params, obs_params,
    #      accumulated_reward) = carry
    #     task_state = task_state.replace(
    #         obs=obs_norm_fn(task_state.obs[None, :], obs_params))
    #     act, policy_state = act_fn(task_state, params[None, :], policy_state)
    #     task_state = task_state.replace(obs=task_state.obs[0])
    #     task_state = env.step(task_state, act[0])
    #     policy_state = update_fn(params[None, :], policy_state, None)
    #     accumulated_reward = accumulated_reward + task_state.reward
    #
    #     return ((task_state, policy_state, params, obs_params, accumulated_reward), (task_state))
    if target is None:
        target = {}
    env_fn = envs.create_fn(
        env_name=env_name,
        legacy_spring=True,
        # terminate_when_unhealthy=args.terminate_when_unhealthy,
        **target
    )
    env = env_fn()
    # state = env.reset(rng=jp.random_prngkey(seed=0))
    task_reset_fn = jax.jit(env.reset)
    policy_reset_fn = jax.jit(policy.reset)
    step_fn = jax.jit(env.step)
    act_fn = jax.jit(policy.get_actions)
    # update_fn = jax.jit(policy.update_fn) if hasattr(policy, 'update_fn') else lambda params, p_state, t_state: p_state
    obs_norm_fn = jax.jit(obs_normalizer.normalize_obs)

    total_reward = 0
    rollout = []
    rewards = []
    ws = []
    rng = jax.random.PRNGKey(42 + 1)
    task_state = task_reset_fn(rng=rng)
    policy_state = policy_reset_fn(task_state)

    # accumulated_rewards = jnp.zeros((1, ))
    # task_states = jax.lax.scan(
    #     step_once,
    #     (task_state, policy_state, params, obs_params, accumulated_rewards),
    #     (), 1000
    # )
    # print(task_states)

    step = 0
    while not task_state.done:
        rollout.append(task_state)
        task_state = task_state.replace(
            obs=obs_norm_fn(task_state.obs[None, :], obs_params))
        # jax.debug.breakpoint()
        act, policy_state = act_fn(task_state, params[None, :], policy_state)
        # For 50 steps, completely zero out the weights to see if the policy can
        # relearn weights that allow the ant to walk.
        if step > 500 and step < 550 and injury:
            params *= 0
            # policy_state.fast_Ws[1] *= 0

        # jax.debug.breakpoint()
        task_state = task_state.replace(obs=task_state.obs[0])
        task_state = step_fn(task_state, act)
        # task_state = env.step(task_state, act[0])
        # policy_state = update_fn(params[None, :], policy_state, None)
        total_reward = total_reward + task_state.reward
        rewards.append(task_state.reward)
        # Record the weights every 10 steps for visualisations.
        if hasattr(policy_state, 'fast_Ws') and step % 10 == 0:
            ws.append(policy_state.fast_Ws)
        step += 1

        if step % 100 == 0 and plot:
            print('[Eval with injury] {}, reward:{:.3e}'.format(step, total_reward))
    print('[Eval with injury] rollout reward = {}'.format(total_reward))

    if plot:
        ws = list(zip(*ws))
        for i, w in enumerate(ws):
            w = np.array(jnp.concatenate(w)[jnp.newaxis, :, jnp.newaxis, :, :])
            # TODO: w

        html.save_html(os.path.join(output_dir, 'eval_with_injury_{}.html'.format(target)), env.sys, [s.qp for s in rollout])

        fig, ax = plt.subplots()
        ax.plot(rewards)
        plt.savefig(os.path.join(output_dir, 'BraxMetaLearning_{}.pdf').format(target))

    return rewards, rollout

# %% [markdown]
# ### Test Generalizability

# %%
# env = 'ant_dir'  # halfcheetah_vel
num_tasks = 8
hidden_dims = [128]
resume_meta = f'{root_dir}/checkpoints/RL_exp/meta/'

resume_base = f'{root_dir}/checkpoints/RL_exp/base/'

env_names = ['ant_dir',  'swimmer_dir', 'halfcheetah_vel', 'hopper_vel', 'fetch', 'ur5e']

xs, y_metas, y_bases = [], [], []
for idx, env in enumerate(env_names):
    print(env)
    train_task = BraxTask(
        env_name=env,
        test=False,
        num_tasks=num_tasks
        # terminate_when_unhealthy=args.terminate_when_unhealthy
    )
    policy_meta = getattr(evojax.policy, 'MetaStdpMLPPolicy')(
        input_dim=train_task.obs_shape[0],
        hidden_dims=[
            *hidden_dims,
        ],
        output_dim=train_task.act_shape[0],
    )

    policy_base = getattr(evojax.policy, 'MLPSnnPolicy')(
        input_dim=train_task.obs_shape[0],
        hidden_dims=[
            *hidden_dims,
        ],
        output_dim=train_task.act_shape[0],
    )

    meta_best_params, meta_obs_params, meta_epoch, meta_best_score, meta_steps = load_model(model_dir=resume_meta, fname=f'{env}.npz')
    base_best_params, base_obs_params, base_epoch, base_best_score, base_steps = load_model(model_dir=resume_base, fname=f'{env}.npz')
    meta_obs_normalizer = ObsNormalizer(obs_shape=train_task.obs_shape, task_info_holder=train_task.task_info_holder)
    base_obs_normalizer = ObsNormalizer(obs_shape=train_task.obs_shape, task_info_holder=train_task.task_info_holder)

    x, y_meta, y_base = [], [], []
    if env in ['fetch', 'ur5e']:
        meta_rewards, meta_rollout = \
            eval_with_injury(policy_meta, env, meta_obs_normalizer, meta_best_params, meta_obs_params, target=None, injury=False, plot=False)
        base_rewards, base_rollout = \
            eval_with_injury_base(policy_base, env, base_obs_normalizer, base_best_params, base_obs_params, target=None, injury=False, plot=False)
        x.append([0])
        y_meta.append(meta_rewards)
        y_base.append(base_rewards)

    else:
        for i in range(72):
            print('{} / 72'.format(i))
            _min = train_task.task_min + (train_task.task_max - train_task.task_min) / 8
            _max = train_task.task_max - (train_task.task_max - train_task.task_min) / 8
            target = (1 - i / 72) * train_task.task_min + i / 72 * train_task.task_max
            _target = (1 - i / 72) * _min + i / 72 * _max
            meta_rewards, meta_rollout = \
                eval_with_injury(policy_meta, env, meta_obs_normalizer, meta_best_params, meta_obs_params, target={train_task.task_kwargs: _target}, injury=False, plot=False)
            base_rewards, base_rollout = \
                eval_with_injury_base(policy_base, env, base_obs_normalizer, base_best_params, base_obs_params, target={train_task.task_kwargs: _target}, injury=False, plot=False)
            x.append(target)
            y_meta.append(sum(meta_rewards))
            y_base.append(sum(base_rewards))

    xs.append(x)
    y_metas.append(y_meta)
    y_bases.append(y_base)
# Out:
# ant_dir
# MLPPolicy: 2023-07-19 16:43:29,017 [INFO] MLPPolicy.num_params = 4744
# (28,) (8,)
# (28,)
# (28,)
# 0 / 72
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 5276.5439453125
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 992.3375244140625
# 1 / 72
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 5328.2880859375
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 992.4791870117188
# 2 / 72
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 5304.2421875
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 992.156005859375
# 3 / 72
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 5273.88720703125
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 996.326171875
# 4 / 72
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 5268.14697265625
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 995.6050415039062
# 5 / 72
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 5297.8095703125
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 995.66650390625
# 6 / 72
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 5316.27978515625
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 996.1600952148438
# 7 / 72
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 5385.30224609375
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 996.08837890625
# 8 / 72
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 5379.9091796875
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 996.6585083007812
# 9 / 72
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 5274.5908203125
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 996.0849609375
# 10 / 72
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 5350.484375
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 996.7323608398438
# 11 / 72
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 5370.771484375
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 997.71337890625
# 12 / 72
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 5388.68017578125
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 998.377685546875
# 13 / 72
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 5370.24169921875
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 998.60546875
# 14 / 72
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 5300.9287109375
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 998.7442626953125
# 15 / 72
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 5442.833984375
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 998.8329467773438
# 16 / 72
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 5415.259765625
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 999.4085693359375
# 17 / 72
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 5342.28271484375
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 999.8866577148438
# 18 / 72
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 5393.8740234375
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 998.6453247070312
# 19 / 72
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 5415.416015625
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 999.5463256835938
# 20 / 72
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 5384.76611328125
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 999.0087280273438
# 21 / 72
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 5404.6806640625
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 999.6290283203125
# 22 / 72
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 5445.833984375
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 999.76318359375
# 23 / 72
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 5426.07275390625
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 1000.1583251953125
# 24 / 72
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 5251.93212890625
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 998.1874389648438
# 25 / 72
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 5415.3359375
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 998.5425415039062
# 26 / 72
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 5360.29541015625
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 999.8574829101562
# 27 / 72
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 5459.89892578125
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 1000.0510864257812
# 28 / 72
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 5449.27197265625
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 998.612060546875
# 29 / 72
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 5421.91845703125
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 998.7601318359375
# 30 / 72
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 5262.1611328125
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 998.7373657226562
# 31 / 72
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 5392.22900390625
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 998.8258666992188
# 32 / 72
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 5407.40087890625
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 998.5156860351562
# 33 / 72
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 5422.703125
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 998.0362548828125
# 34 / 72
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 5314.0556640625
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 997.8306274414062
# 35 / 72
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 5404.4326171875
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 997.6726684570312
# 36 / 72
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 5413.39306640625
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 996.7803955078125
# 37 / 72
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 5431.01171875
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 940.591552734375
# 38 / 72
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 5428.6376953125
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 995.9129638671875
# 39 / 72
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 5448.19580078125
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 995.676025390625
# 40 / 72
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 5390.638671875
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 994.7571411132812
# 41 / 72
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 5428.00048828125
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 961.4261474609375
# 42 / 72
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 5391.3916015625
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 990.7882080078125
# 43 / 72
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 5401.197265625
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 1063.959228515625
# 44 / 72
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 5387.7861328125
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 1144.7027587890625
# 45 / 72
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 5295.59619140625
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 1236.0321044921875
# 46 / 72
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 5385.626953125
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 1285.05224609375
# 47 / 72
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 5351.6630859375
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 1367.9822998046875
# 48 / 72
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 5320.12255859375
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 1444.5504150390625
# 49 / 72
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 5347.38427734375
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 1509.409912109375
# 50 / 72
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 5314.2294921875
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 1560.8096923828125
# 51 / 72
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 5348.48681640625
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 1648.630615234375
# 52 / 72
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 5374.45751953125
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 1683.70703125
# 53 / 72
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 5358.8203125
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 1731.4964599609375
# 54 / 72
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 5388.4921875
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 1806.94677734375
# 55 / 72
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 5346.1884765625
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 1821.9990234375
# 56 / 72
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 5371.60595703125
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 1855.1376953125
# 57 / 72
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 5368.70458984375
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 1897.7142333984375
# 58 / 72
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 5295.74609375
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 1944.0721435546875
# 59 / 72
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 5354.384765625
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 1944.530029296875
# 60 / 72
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 5284.69482421875
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 1955.7235107421875
# 61 / 72
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 5293.21533203125
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 1979.0985107421875
# 62 / 72
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 5292.98583984375
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 1990.8873291015625
# 63 / 72
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 5238.48681640625
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 1998.4239501953125
# 64 / 72
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 5282.73828125
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 1952.796142578125
# 65 / 72
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 5211.9130859375
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 1971.71044921875
# 66 / 72
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 5196.759765625
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 1931.1141357421875
# 67 / 72
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 5247.32666015625
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 1918.8199462890625
# 68 / 72
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 5209.75390625
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 1897.889892578125
# 69 / 72
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 5119.56689453125
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 1864.239501953125
# 70 / 72
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 5236.22216796875
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 1802.7235107421875
# 71 / 72
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 5143.39892578125
# (1, 1) (1, 27)
# [Eval with injury] rollout reward = 1758.0472412109375
# swimmer_dir
# (9,) (2,)
# MLPPolicy: 2023-07-19 17:06:39,240 [INFO] MLPPolicy.num_params = 1538
# (9,)
# (9,)
# 0 / 72
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 7512.09912109375
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 71.41179656982422
# 1 / 72
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 8171.771484375
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 69.84249114990234
# 2 / 72
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 8772.8349609375
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 67.1768798828125
# 3 / 72
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 9541.8203125
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 65.42288208007812
# 4 / 72
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 10315.08203125
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 40.758026123046875
# 5 / 72
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 11141.7294921875
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 19.672550201416016
# 6 / 72
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 11932.427734375
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 6.723092079162598
# 7 / 72
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 12577.34375
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 3.9979281425476074
# 8 / 72
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 12999.1708984375
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 8.27860164642334
# 9 / 72
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 13930.2626953125
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 7.104656219482422
# 10 / 72
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 14578.5361328125
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 27.10642433166504
# 11 / 72
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 15313.43359375
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 27.045320510864258
# 12 / 72
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 15907.853515625
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 29.454856872558594
# 13 / 72
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 16363.009765625
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 30.051315307617188
# 14 / 72
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 17197.921875
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 31.214927673339844
# 15 / 72
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 17351.185546875
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 31.48464012145996
# 16 / 72
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 17757.197265625
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 34.35300064086914
# 17 / 72
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 17683.666015625
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 35.484344482421875
# 18 / 72
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 18508.880859375
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 36.56658935546875
# 19 / 72
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 18418.123046875
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 38.40365219116211
# 20 / 72
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 18254.62890625
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 39.5304069519043
# 21 / 72
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 17325.130859375
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 40.05854797363281
# 22 / 72
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 18632.494140625
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 43.99759292602539
# 23 / 72
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 19851.74609375
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 44.703731536865234
# 24 / 72
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 19929.30078125
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 46.06098175048828
# 25 / 72
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 19264.337890625
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 46.444766998291016
# 26 / 72
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 19938.2734375
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 46.700523376464844
# 27 / 72
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 18870.228515625
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 46.18400192260742
# 28 / 72
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 19300.78515625
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 45.62858200073242
# 29 / 72
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 19610.9140625
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 41.49805450439453
# 30 / 72
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 19163.6328125
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 35.11964797973633
# 31 / 72
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 17916.455078125
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 32.3264045715332
# 32 / 72
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 18318.8125
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 38.60050582885742
# 33 / 72
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 17984.07421875
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 38.775962829589844
# 34 / 72
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 19074.22265625
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 40.405059814453125
# 35 / 72
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 18889.751953125
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 41.16606903076172
# 36 / 72
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 19128.17578125
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 40.2874870300293
# 37 / 72
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 18332.32421875
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 35.027198791503906
# 38 / 72
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 17912.05859375
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 30.369483947753906
# 39 / 72
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 14365.4169921875
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 23.89311981201172
# 40 / 72
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = -325.4902038574219
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 2.2001490592956543
# 41 / 72
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 10423.2001953125
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 3.6482536792755127
# 42 / 72
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 10627.5126953125
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 4.551130294799805
# 43 / 72
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 13707.1640625
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 6.321808338165283
# 44 / 72
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 15411.796875
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 7.086943626403809
# 45 / 72
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 16774.125
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 8.28846263885498
# 46 / 72
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 17168.99609375
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 7.752710342407227
# 47 / 72
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 17213.6484375
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 9.705904960632324
# 48 / 72
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 17035.1875
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 8.301118850708008
# 49 / 72
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 16881.638671875
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 7.805462837219238
# 50 / 72
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 17127.638671875
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 7.494622230529785
# 51 / 72
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 17169.232421875
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 7.603539943695068
# 52 / 72
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 16888.43359375
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 5.940585136413574
# 53 / 72
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 16701.421875
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = -4.406551361083984
# 54 / 72
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 16661.853515625
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = -1.8684775829315186
# 55 / 72
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 16391.16796875
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = -3.8456194400787354
# 56 / 72
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 16215.1884765625
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = -4.335185527801514
# 57 / 72
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 15633.814453125
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = -4.592705249786377
# 58 / 72
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 15799.71875
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = -3.969043016433716
# 59 / 72
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 14987.90234375
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = -3.025027275085449
# 60 / 72
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 14963.3779296875
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = -2.7001001834869385
# 61 / 72
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 14280.84375
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = -1.1885899305343628
# 62 / 72
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 13434.7548828125
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = -0.3627142012119293
# 63 / 72
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 13087.4111328125
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 0.7597212791442871
# 64 / 72
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 12487.5419921875
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 0.6917301416397095
# 65 / 72
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 11846.2373046875
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 2.345224142074585
# 66 / 72
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 11395.3544921875
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 3.6157143115997314
# 67 / 72
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 10660.171875
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 4.909237384796143
# 68 / 72
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 9945.359375
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 5.041594982147217
# 69 / 72
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 9174.4814453125
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 5.267317295074463
# 70 / 72
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 8480.279296875
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 6.189554214477539
# 71 / 72
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 7814.84716796875
# (1, 1) (1, 8)
# [Eval with injury] rollout reward = 6.319333553314209
# halfcheetah_vel
# (19,) (6,)
# MLPPolicy: 2023-07-19 17:21:05,673 [INFO] MLPPolicy.num_params = 3334
# (19,)
# (19,)
# 0 / 72
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -210.81076049804688
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -280.9963073730469
# 1 / 72
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -217.5007781982422
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -337.4419250488281
# 2 / 72
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -308.7626037597656
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -292.24957275390625
# 3 / 72
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -360.25732421875
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -370.5157775878906
# 4 / 72
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -432.80206298828125
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -393.028076171875
# 5 / 72
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -484.93707275390625
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -530.5087890625
# 6 / 72
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -408.81658935546875
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -544.361572265625
# 7 / 72
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -375.69708251953125
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -478.08453369140625
# 8 / 72
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -324.939697265625
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -573.7252197265625
# 9 / 72
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -304.1700439453125
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -631.796142578125
# 10 / 72
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -350.9795837402344
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -480.6455383300781
# 11 / 72
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -342.03558349609375
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -532.3429565429688
# 12 / 72
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -330.07696533203125
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -525.9310302734375
# 13 / 72
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -344.02606201171875
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -566.6839599609375
# 14 / 72
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -418.7770690917969
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -589.5143432617188
# 15 / 72
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -366.4527893066406
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -2611.354248046875
# 16 / 72
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -413.0474548339844
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -667.2127075195312
# 17 / 72
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -407.6926574707031
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -693.0610961914062
# 18 / 72
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -414.6310119628906
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -835.6144409179688
# 19 / 72
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -405.45257568359375
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -864.5381469726562
# 20 / 72
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -408.77008056640625
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -865.1546630859375
# 21 / 72
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -436.5108642578125
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -983.6209106445312
# 22 / 72
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -390.38092041015625
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -1091.9420166015625
# 23 / 72
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -385.9401550292969
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -1273.5528564453125
# 24 / 72
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -417.2879333496094
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -1257.94970703125
# 25 / 72
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -450.0821838378906
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -1233.3720703125
# 26 / 72
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -456.8580322265625
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -1403.758544921875
# 27 / 72
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -457.26947021484375
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -1446.18603515625
# 28 / 72
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -492.0224609375
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -1633.6617431640625
# 29 / 72
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -506.80279541015625
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -1652.2772216796875
# 30 / 72
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -559.9656982421875
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -1800.715087890625
# 31 / 72
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -585.8399047851562
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -1970.993896484375
# 32 / 72
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -555.3942260742188
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -1936.1749267578125
# 33 / 72
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -567.9384765625
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -1983.900634765625
# 34 / 72
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -502.1112976074219
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -2104.934326171875
# 35 / 72
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -628.7041015625
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -2179.8984375
# 36 / 72
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -575.0565795898438
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -2282.940185546875
# 37 / 72
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -564.7832641601562
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -2372.18359375
# 38 / 72
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -586.0799560546875
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -2532.938720703125
# 39 / 72
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -554.5880737304688
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -2603.813232421875
# 40 / 72
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -827.1211547851562
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -2823.401123046875
# 41 / 72
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -604.6244506835938
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -2851.440185546875
# 42 / 72
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -794.9046020507812
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -2890.226318359375
# 43 / 72
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -652.0518188476562
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -3031.67919921875
# 44 / 72
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -622.600830078125
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -3091.7041015625
# 45 / 72
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -808.7800903320312
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -3150.387451171875
# 46 / 72
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -679.44287109375
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -3294.522705078125
# 47 / 72
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -642.561767578125
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -3344.61572265625
# 48 / 72
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -680.903076171875
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -3394.44189453125
# 49 / 72
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -701.5629272460938
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -3534.29541015625
# 50 / 72
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -679.0355224609375
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -3608.782470703125
# 51 / 72
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -924.8748779296875
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -3786.044189453125
# 52 / 72
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -741.0838623046875
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -3769.4013671875
# 53 / 72
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -710.8190307617188
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -3922.8974609375
# 54 / 72
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -906.4083251953125
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -4001.741455078125
# 55 / 72
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -822.7434692382812
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -4149.09521484375
# 56 / 72
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -725.6862182617188
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -4311.48828125
# 57 / 72
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -1235.691650390625
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -4305.205078125
# 58 / 72
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -741.462158203125
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -4439.6923828125
# 59 / 72
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -796.4336547851562
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -4486.8369140625
# 60 / 72
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -1198.4984130859375
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -4538.74951171875
# 61 / 72
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -841.1151123046875
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -4576.66943359375
# 62 / 72
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -849.2437133789062
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -4663.775390625
# 63 / 72
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -1166.7601318359375
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -4678.21826171875
# 64 / 72
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -999.4259643554688
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -4853.27001953125
# 65 / 72
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -1095.164306640625
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -4912.857421875
# 66 / 72
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -922.824951171875
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -5157.8271484375
# 67 / 72
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -962.6076049804688
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -5268.146484375
# 68 / 72
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -867.3402099609375
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -5383.57080078125
# 69 / 72
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -1133.616455078125
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -5383.787109375
# 70 / 72
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -1074.14501953125
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -5535.08154296875
# 71 / 72
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -1153.813720703125
# (1, 1) (1, 18)
# [Eval with injury] rollout reward = -5597.0625
# hopper_vel
# (12,) (3,)
# MLPPolicy: 2023-07-19 17:42:37,932 [INFO] MLPPolicy.num_params = 2051
# (12,)
# (12,)
# 0 / 72
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 972.3192138671875
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 948.226318359375
# 1 / 72
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 970.5274047851562
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 952.3864135742188
# 2 / 72
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 960.1448974609375
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 942.4208984375
# 3 / 72
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 947.514404296875
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 931.7925415039062
# 4 / 72
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 937.3410034179688
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 922.3281860351562
# 5 / 72
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 933.3665771484375
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 912.3126831054688
# 6 / 72
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 926.049560546875
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 901.303955078125
# 7 / 72
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 935.8623657226562
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 912.2181396484375
# 8 / 72
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 942.9891357421875
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 922.6610717773438
# 9 / 72
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 961.2642822265625
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 922.9951782226562
# 10 / 72
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 962.8798828125
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 927.3693237304688
# 11 / 72
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 965.8893432617188
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 930.4620971679688
# 12 / 72
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 965.33642578125
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 921.8312377929688
# 13 / 72
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 962.4974365234375
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 922.5580444335938
# 14 / 72
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 957.3623657226562
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 924.6203002929688
# 15 / 72
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 955.449951171875
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 920.0029907226562
# 16 / 72
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 952.3302001953125
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 912.1240844726562
# 17 / 72
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 934.2069091796875
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 909.3484497070312
# 18 / 72
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 945.3425903320312
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 911.421630859375
# 19 / 72
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 955.1668701171875
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 902.21044921875
# 20 / 72
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 955.1676635742188
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 898.9279174804688
# 21 / 72
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 951.050048828125
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 900.215087890625
# 22 / 72
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 955.6432495117188
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 895.940185546875
# 23 / 72
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 958.357177734375
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 896.4686889648438
# 24 / 72
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 957.8941650390625
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 894.373779296875
# 25 / 72
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 957.4544677734375
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 892.9481811523438
# 26 / 72
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 950.56787109375
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 884.8756103515625
# 27 / 72
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 947.8298950195312
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 883.61962890625
# 28 / 72
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 947.7664184570312
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 879.3619995117188
# 29 / 72
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 947.4154052734375
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 876.8995361328125
# 30 / 72
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 945.826416015625
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 873.7369384765625
# 31 / 72
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 941.8993530273438
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 873.1085815429688
# 32 / 72
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 943.5740966796875
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 875.0966186523438
# 33 / 72
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 941.6710205078125
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 878.3201293945312
# 34 / 72
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 939.4988403320312
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 875.9091796875
# 35 / 72
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 937.6332397460938
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 870.9103393554688
# 36 / 72
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 930.3036499023438
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 871.4907836914062
# 37 / 72
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 934.5811767578125
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 864.5680541992188
# 38 / 72
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 931.0029296875
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 866.8495483398438
# 39 / 72
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 929.7835693359375
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 861.5890502929688
# 40 / 72
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 919.3196411132812
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 862.8591918945312
# 41 / 72
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 926.4384155273438
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 853.545166015625
# 42 / 72
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 921.8732299804688
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 849.23193359375
# 43 / 72
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 918.8104858398438
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 849.9907836914062
# 44 / 72
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 914.7344970703125
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 846.955810546875
# 45 / 72
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 919.95947265625
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 846.6860961914062
# 46 / 72
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 917.3807373046875
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 834.3152465820312
# 47 / 72
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 912.5081176757812
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 836.9913940429688
# 48 / 72
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 912.722412109375
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 832.7489013671875
# 49 / 72
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 909.214111328125
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 824.7045288085938
# 50 / 72
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 905.3765869140625
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 824.6610107421875
# 51 / 72
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 905.6701049804688
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 814.319580078125
# 52 / 72
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 902.654541015625
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 819.2723999023438
# 53 / 72
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 895.5359497070312
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 812.1846923828125
# 54 / 72
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 897.8475341796875
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 806.7210693359375
# 55 / 72
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 893.8609008789062
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 806.2415771484375
# 56 / 72
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 890.794189453125
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 798.4076538085938
# 57 / 72
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 890.113037109375
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 798.9777221679688
# 58 / 72
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 888.1734619140625
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 790.1389770507812
# 59 / 72
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 887.772216796875
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 785.3291015625
# 60 / 72
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 885.0986938476562
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 781.8624877929688
# 61 / 72
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 877.8488159179688
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 775.894775390625
# 62 / 72
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 881.293701171875
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 770.679931640625
# 63 / 72
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 871.5059814453125
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 759.47998046875
# 64 / 72
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 870.5958251953125
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 759.078125
# 65 / 72
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 870.8168334960938
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 750.7672119140625
# 66 / 72
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 865.0801391601562
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 747.1102294921875
# 67 / 72
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 861.9716796875
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 744.371826171875
# 68 / 72
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 859.5607299804688
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 739.0060424804688
# 69 / 72
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 854.622314453125
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 734.0399780273438
# 70 / 72
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 852.1088256835938
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 720.5796508789062
# 71 / 72
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 846.8666381835938
# (1, 1) (1, 11)
# [Eval with injury] rollout reward = 716.694580078125
# fetch
# (101,) (10,)
# MLPPolicy: 2023-07-19 18:01:44,120 [INFO] MLPPolicy.num_params = 14346
# (101,)
# (101,)
# (1, 0) (1, 101)
# [Eval with injury] rollout reward = 62.750938415527344
# (1, 0) (1, 101)
# [Eval with injury] rollout reward = 11.805059432983398
# ur5e
# (66,) (6,)
# MLPPolicy: 2023-07-19 18:02:06,213 [INFO] MLPPolicy.num_params = 9350
# (66,)
# (66,)
# (1, 0) (1, 66)
# [Eval with injury] rollout reward = 109.0873794555664
# (1, 0) (1, 66)
# [Eval with injury] rollout reward = 5.2074174880981445

# %%
fig = plt.figure(figsize=(18, 3), dpi=100, constrained_layout=True)
spec = fig.add_gridspec(nrows=1, ncols=6, figure=fig)  #, width_ratios=[.2, 1, 1, 1, 1, .08, 1.6], height_ratios=[0.02, 1, 1, 0.01])

xlabels = ['direction ($\degree$)', 'direction ($\degree$)', 'velocity (m/s)', 'velocity (m/s)', 'step', 'step']
ylabels = ['', '', 'Episode Reward', 'Episode Reward', 'Episode Reward', 'Episode Reward']

for idx, env in enumerate(env_names):

    x = xs[idx]
    y_meta = y_metas[idx]
    y_base = y_bases[idx]


    if idx in [0, 1]:
        ax = fig.add_subplot(spec[0, idx], projection='polar')
    else:
        ax = fig.add_subplot(spec[0, idx])

    if idx in [0, 1, 2, 3]:
        xx = x[::9]
        yy_meta = y_meta[::9]
        yy_base = y_base[::9]

        plt.scatter(x, y_meta)
        plt.scatter(xx, yy_meta)
        plt.scatter(x, y_base)
        plt.scatter(xx, yy_base)

        # plt.ylim(0, 6000)
        # plt.legend(['$Test_{Plasticity}$', '$Train_{Plasticity}$', '$Test_{Weight}$', '$Train_{Weight}$'])
        if idx == 0:
            plt.legend(labels=['$Test_{Plasticity}$', '$Train_{Plasticity}$', '$Test_{Weight}$', '$Train_{Weight}$'], loc=2, bbox_to_anchor=(-1.05,1))
    else:
        y_meta = np.array(list(y_meta)).reshape(-1)
        y_base = np.array(list(y_base)).reshape(-1)
        plt.plot(np.cumsum(y_meta))
        plt.plot(np.cumsum(y_base))
        plt.legend(['$Test_{Plasticity}$', '$Test_{Weight}$'])

    ax.set_xlabel(xlabels[idx])
    ax.set_ylabel(ylabels[idx])
    ax.set_title(env)
    ax.ticklabel_format(style='sci', scilimits=(-1,2), axis='y')

plt.savefig(os.path.join(output_dir, 'generalize.pdf'), format='pdf', bbox_inches='tight')
plt.show()
